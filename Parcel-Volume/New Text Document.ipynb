# %%
import geopandas as gpd
# from spatial_kde import spatial_kernel_density
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from shapely.geometry import Polygon, MultiPolygon

# %%
Volumeshape = gpd.read_file(r"E:\Projects\Replace-Arcpy-In-TDM\Create-Walk-Buffer\Inputs\TAZ.shp")
Volumeshape.head()
# Out:
#    TAZID  SORT  CO_TAZID  SUBAREAID  EXTERNAL   ACRES  DEVACRES             X  \
# 0    460     1    110460          1         0  322.29    322.29  409807.97148
# 1    461     2    110461          1         0  316.91    316.91  409818.05584
# 2    656     3    350656          1         0  828.83    701.91  407896.91458
# 3    657     4    350657          1         0  531.35    531.28  409430.46088
# 4   2696     5    492696          1         0  575.28    574.81  435443.25244
#
#               Y  ADJ_XY  ...      DLRG_NAME  DISTMED                DMED_NAME  \
# 0  4.551224e+06       0  ...    North Davis       11  Clinton-W.Pt-Clearfield
# 1  4.552025e+06       0  ...    North Davis       11  Clinton-W.Pt-Clearfield
# 2  4.518164e+06       0  ...  North-west SL       17    NW Quad-International
# 3  4.518727e+06       0  ...  North-west SL       17    NW Quad-International
# 4  4.435982e+06       0  ...      Southwest       45             Payson-Salem
#
#    DISTSML                DSML_NAME  AIRSAGE  WF_AIRSAGE  SLC  \
# 0       98  Clinton-W.Pt-Clearfield     1106          13    2
# 1       98  Clinton-W.Pt-Clearfield     1106          13    2
# 2      155    NW Quad-International     3518          32    1
# 3      155    NW Quad-International     3518          32    1
# 4      550             Payson-Salem     4907          43    2
#
#               NAAPM25                                           geometry
# 0  NonAttnmnt|11|WFRC  POLYGON ((409006.359 4551638.527, 410620.289 4...
# 1  NonAttnmnt|11|WFRC  POLYGON ((410620.289 4551617.451, 409006.359 4...
# 2  NonAttnmnt|35|WFRC  POLYGON ((408728.616 4519566.606, 408712.008 4...
# 3  NonAttnmnt|35|WFRC  POLYGON ((408712.008 4517726.403, 408728.616 4...
# 4   NonAttnmnt|49|MAG  POLYGON ((436219.451 4436668.967, 436211.880 4...
#
# [5 rows x 41 columns]
